# %%
from utils_vae import read_field
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Model

# import keras 
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.losses import mse
# import sys, importlib

# from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import LearningRateScheduler
# from tensorflow.keras.utils import plot_model
import tensorflow as tf

from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input, Dense,Flatten,Concatenate ,Conv1D
from VAES import dense_gen,cloud_model,schedule

from tensorflow.keras import regularizers
from tensorflow.keras import initializers
# Out:
# 2022-11-21 05:32:37.282065: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /glade/u/apps/ch/opt/mpt_fmods/2.25/intel/19.1.1:/glade/u/apps/ch/opt/mpt/2.25/lib:/glade/u/apps/opt/intel/2020u1/compilers_and_libraries/linux/lib/intel64:/glade/u/apps/ch/os/usr/lib64:/glade/u/apps/ch/os/usr/lib:/glade/u/apps/ch/os/lib64:/glade/u/apps/ch/os/lib
# 2022-11-21 05:32:37.282101: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path = "/glade/scratch/sshamekh/dyamond/SAM_highres/"

# %%time
import sys, importlib
importlib.reload(sys.modules['utils_vae'])
from utils_vae import train_test_data,read_data_for_z
t1 = 0
t2 = 8
high_res = 4.0 # km 
large_scale = 128 #km
x_hr,x_lg,x_lg2, y_out = read_data_for_z(path, high_res,large_scale,t1,t2,threshold_precip = 0.01,mask_threshold = False)
# Out:
# Reading high resolution input
# qvi
# no scaling
# (760, 24, 287, 32, 32, 1)
# Reading large-scale inputs
# qvi
# ts
# tas
# huss
# (760, 24, 287, 4)
# Reading large-scale inputs2
# vas
# uas
# hfss
# hfls
# (760, 24, 287, 4)
# Reading large-scale outputs
# pracc
# (760, 24, 287, 1)
# [[[[0.8208742125920748]]]]

# %%
pw_anomaly = x_hr - np.mean(x_hr,axis = (3,4),keepdims=True)
x_lg = np.concatenate((x_lg,x_lg2[:,:,:,2:]),axis = -1)

# %%
def make_z(hrdata,lgdata):
    path = '/glade/u/home/sshamekh/results/dyamond/4nodes/'
    encoder_result= keras.models.load_model(path + 'encoder_4_32_mse_anomaly')
    precip_nn =  keras.models.load_model(path + 'precip_dense_vae_4_32_mse_anomaly')
    
    tt,lat,lon,nx,ny,ff = hrdata.shape
    hrdata = hrdata.reshape(tt*lat*lon,nx,ny,ff)
    lgd = lgdata.reshape(tt*lat*lon,-1)
    
    zall = encoder_result.predict(hrdata)
    innew = np.concatenate((zall,lgd),axis = -1)
    precip = precip_nn.predict(innew)
    zall = zall.reshape(tt,lat,lon,zall.shape[-1])
    return zall,precip

z_true,precip = make_z(pw_anomaly*2,x_lg)
# Out:
# 2022-11-21 05:56:45.820427: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /glade/u/apps/ch/opt/mpt_fmods/2.25/intel/19.1.1:/glade/u/apps/ch/opt/mpt/2.25/lib:/glade/u/apps/opt/intel/2020u1/compilers_and_libraries/linux/lib/intel64:/glade/u/apps/ch/os/usr/lib64:/glade/u/apps/ch/os/usr/lib:/glade/u/apps/ch/os/lib64:/glade/u/apps/ch/os/lib
# 2022-11-21 05:56:45.820481: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-21 05:56:45.820507: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r8i3n11): /proc/driver/nvidia/version does not exist
# 2022-11-21 05:56:45.843816: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 2022-11-21 05:57:09.310021: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 21442068480 exceeds 10% of free system memory.
# 163590/163590 [==============================] - 198s 1ms/step
# 163590/163590 [==============================] - 138s 844us/step

# %%
def grad(data_o):
    data = np.copy(data_o)
    data[1:,:,:,:] = data[1:,:,:,:] - data[:-1,:,:,:]
    data[0,:,:,: ] = data[1,:,:,:]
    return data 
z_grad  = grad(z_true)

# %%
plt.hist(z_true[:,:,:,3].flatten(),bins = 100)
z_true.shape
# Out:
# (760, 24, 287, 4)

# %%
def rand(nn):
    import random
    random.seed(9001)
    x = [random.randint(1,100) for i in range(0,nn)]
    return np.array(x)
def chunk(data,window):
    for i in range(0,window,2):
        datain = np.copy(data[i:,:])
        nt,nlat,nlon,nfeature = datain.shape
        nchunk = int(nt/window)
        dtin = datain[:nchunk*window ,:,:,:]
        dtin = np.reshape(dtin,(nchunk,window,nlat,nlon,nfeature))
        if i==0: 
            data_all = np.copy(dtin)
        else: 
            data_all = np.concatenate((data_all,dtin),axis = 0 )
    print (data_all.shape,'data_all')
    return data_all



def chunk_horizontal(data,window):
    for i in range(window):
        for j in range(window):
            datain = np.copy(data[:,:,i:,j:])
            nchunk,nw,nlat,nlon,nfeature = datain.shape
            nch_lat = int(nlat/window)
            nch_lon = int(nlon/window)
            dtin = datain[:,:,:nch_lat*window,:nch_lon*window,:]
            dtin = np.reshape(dtin,(nchunk,nw,nch_lat,window,nch_lon,window,nfeature))
            print (dtin.shape)
            dtin = np.moveaxis(dtin,3,4 )
            if i==0 and j==0: 
                data_all = np.copy(dtin)
            else: 
                data_all = np.concatenate((data_all,dtin),axis = 0 )
        return data_all
def reshape_data(data):
    nt,window,nlat,nlon,nfeature = data.shape
    
    dtin = np.moveaxis(data,1,3)
    print (dtin.shape)
    dtin = np.reshape(dtin,(nlat*nlon*nt,window,nfeature))
    return dtin

timeframe=5


x_all =  chunk(x_lg,timeframe)
y_all =  chunk(y_out,timeframe)
zz_all = chunk(z_true,timeframe)
# numbres= chunk(numbres,timeframe)
mask =  rand(y_all.shape[0]) < 70
in_train,in_test = x_all[mask,:,:,:], x_all[~mask,:,:,:]
out_train,out_test = y_all[mask,:,:,:], y_all[~mask,:,:,:]
zz_train,zz_test = zz_all[mask,:,:,:], zz_all[~mask,:,:,:]
# num_train = numbres[mask,:,:,:]
# zz_grad_train,zz_grad_test = zz_grad[mask,:,:,:], zz_grad[~mask,:,:,:]
x_train = reshape_data(in_train)
x_test  = reshape_data (in_test)
y_train = reshape_data(out_train)
y_test = reshape_data(out_test)
# num_train = reshape_data(num_train)

zz_train = reshape_data(zz_train)
zz_test = reshape_data(zz_test)

# zz_grad_train = reshape_data(zz_grad_train)
# zz_grad_test = reshape_data(zz_grad_test)
# Out:
# (454, 5, 24, 287, 6) data_all
# (454, 5, 24, 287, 1) data_all
# (454, 5, 24, 287, 4) data_all
# (299, 24, 287, 5, 6)
# (155, 24, 287, 5, 6)
# (299, 24, 287, 5, 1)
# (155, 24, 287, 5, 1)
# (299, 24, 287, 5, 4)
# (155, 24, 287, 5, 4)

# %%
y_train.shape,x_train.shape, in_train.shape,
# Out:
# ((2266152, 3, 1), (2266152, 3, 6), (329, 3, 24, 287, 6))

# %%
for i in range (timeframe):
    index = np.where(y_train[:,i,0]>.010)[0]
    y_train = y_train[index,:]
    x_train = x_train[index,:]
    zz_train = zz_train[index,:]
    # num_train = num_train[index,:]
    # zz_grad_train = zz_grad_train[index,:]

    index = np.where(y_test[:,-1,0]>.010)[0]
    y_test = y_test[index,:]
    x_test = x_test[index,:]
    zz_test = zz_test[index,:]
# zz_grad_test = zz_grad_test[index,:]

# %%
y_train.shape
# Out:
# (394870, 5, 1)

# %%
mmzz = (np.mean(np.concatenate((zz_test[:,-1,:],zz_train[:,-1,:]),axis = 0),axis = 0,keepdims=True)).reshape(1,1,4)
zzstd = (np.std(np.concatenate((zz_test[:,-1,:],zz_train[:,-1,:]),axis = 0),axis = 0,keepdims=True) ).reshape(1,1,4)
# mmzz_g = (np.mean(np.concatenate((zz_grad_test[:,-1,:],zz_grad_train[:,-1,:]),axis = 0),axis = 0,keepdims=True)).reshape(1,1,2)

# %%
zz_train = (zz_train - mmzz) / zzstd
zz_test = (zz_test - mmzz) / zzstd

# %%
zz_train[:,:2,:].shape
# Out:
# (479885, 2, 4)

# %%
units = [256,512,256,128,64]
l1 = 0e-7

initializer = None
batch_size = 128
epochs = 100
activation = tf.nn.relu
output_shape = 4
inshapeX = x_train[0,2:,:].shape
inzshape = zz_train[0,3:4,:].shape

val_split = 0.2


input_lg = Input(shape=(inshapeX), name='inputs_lg')
in_lg = Flatten()(input_lg)
input_z = Input(shape=(inzshape), name='inputs_z')
in_z = Flatten()(input_z)


intotal = Concatenate(axis  = 1)([in_lg,in_z])

xs =  Dense(units=units[0],activation = activation,kernel_initializer=initializer,
            name = 'dense1')(intotal)

xs =  Dense(units=units[1],activation = activation,kernel_initializer=initializer,
           name = 'dense2')(xs)

xs =  Dense(units=units[2],activation = activation,kernel_initializer=initializer,
           name = 'dense3')(xs)

xs =  Dense(units=units[3],activation = activation,kernel_initializer=initializer,
            name = 'dense4')(xs)
xs =  Dense(units=units[4],activation = activation,kernel_initializer=initializer,
            name = 'dense5')(xs)
y_predict =  Dense(units=output_shape,activation = None,name = 'prediction')(xs)

nn_precip = Model(inputs = [input_lg,input_z],
              outputs = [y_predict]) 

opt = keras.optimizers.Adam(lr=0.0001)

nn_precip.compile(optimizer = opt,loss = 'mse')

earlyStopping=keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='auto')
callback_lr=LearningRateScheduler(schedule,verbose=1)


hist = nn_precip.fit({'inputs_lg' : x_train[:,2:,:],
                      'inputs_z' : zz_train[:,3:4,:],
                   
                      },
                  {'prediction': zz_train[:,4,:]},
                   epochs = epochs,  validation_split = val_split,callbacks= [earlyStopping,callback_lr],
                     batch_size = batch_size,verbose = 1, shuffle=True)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 1/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0437 - val_loss: 0.0374 - lr: 4.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 2/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0372 - val_loss: 0.0378 - lr: 4.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 3/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0369 - val_loss: 0.0359 - lr: 4.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 4/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0366 - val_loss: 0.0354 - lr: 4.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 5/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0364 - val_loss: 0.0368 - lr: 4.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 6/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0362 - val_loss: 0.0357 - lr: 4.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 7/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0359 - val_loss: 0.0360 - lr: 4.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 8/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0359 - val_loss: 0.0353 - lr: 4.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 9/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0357 - val_loss: 0.0356 - lr: 4.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 10/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0357 - val_loss: 0.0352 - lr: 4.0000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 11/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0355 - val_loss: 0.0352 - lr: 4.0000e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 12/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0354 - val_loss: 0.0350 - lr: 4.0000e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 13/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0353 - val_loss: 0.0354 - lr: 4.0000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 14/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0353 - val_loss: 0.0350 - lr: 4.0000e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 15/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0352 - val_loss: 0.0352 - lr: 4.0000e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 16/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0352 - val_loss: 0.0356 - lr: 4.0000e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 17/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0352 - val_loss: 0.0351 - lr: 4.0000e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 18/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0351 - val_loss: 0.0352 - lr: 4.0000e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 19/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0350 - val_loss: 0.0351 - lr: 4.0000e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 20/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0350 - val_loss: 0.0354 - lr: 4.0000e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 21/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0342 - val_loss: 0.0347 - lr: 2.0000e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 22/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0342 - val_loss: 0.0343 - lr: 2.0000e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 23/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0342 - val_loss: 0.0344 - lr: 2.0000e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 24/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0341 - val_loss: 0.0344 - lr: 2.0000e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 25/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0341 - val_loss: 0.0348 - lr: 2.0000e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 26/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0341 - val_loss: 0.0341 - lr: 2.0000e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 27/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0341 - val_loss: 0.0341 - lr: 2.0000e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 28/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0341 - val_loss: 0.0343 - lr: 2.0000e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 29/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0340 - val_loss: 0.0344 - lr: 2.0000e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 30/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0340 - val_loss: 0.0343 - lr: 2.0000e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 31/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0336 - val_loss: 0.0338 - lr: 1.0000e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 32/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0336 - val_loss: 0.0341 - lr: 1.0000e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 33/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0336 - val_loss: 0.0340 - lr: 1.0000e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 34/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0335 - val_loss: 0.0339 - lr: 1.0000e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 35/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0335 - val_loss: 0.0339 - lr: 1.0000e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 36/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0335 - val_loss: 0.0345 - lr: 1.0000e-04
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 37/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0335 - val_loss: 0.0339 - lr: 1.0000e-04
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 38/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0335 - val_loss: 0.0339 - lr: 1.0000e-04
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 39/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0335 - val_loss: 0.0338 - lr: 1.0000e-04
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 40/100
# 2468/2468 [==============================] - 9s 3ms/step - loss: 0.0335 - val_loss: 0.0338 - lr: 1.0000e-04
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 41/100
# 2468/2468 [==============================] - 9s 4ms/step - loss: 0.0335 - val_loss: 0.0339 - lr: 1.0000e-04

# %%
zz_predict= nn_precip.predict([x_train[:,2:,:],zz_train[:,3:4,:]])
# Out:
# 12340/12340 [==============================] - 12s 1ms/step

# %%
data = np.concatenate((zz_train[:,4,:].reshape(-1,4,1),zz_predict.reshape(-1,4,1)),axis = -1)
np.save('dt2_lg_dt1_org.npy',data)

# %%
from sklearn.metrics import r2_score
r2s = [r2_score(zz_train[:,4,0],zz_predict[:,0]),r2_score(zz_train[:,-1,1],zz_predict[:,1]),r2_score(zz_train[:,-1,2],zz_predict[:,2]),r2_score(zz_train[:,-1,3],zz_predict[:,3])]

# %%
data.shape
# Out:
# (394870, 4, 2)

# %%
r2s,#Linnia.hawkins@oregonstate.edu
# Out:
# ([-15.021454036630956,
#   -0.21666193367855402,
#   -0.21948087509486203,
#   -0.14070131901501415],)

# %%
fig = plt.figure(figsize=[26,5])
xx = [-10,-5.5,-5.8,-15]
yy = [2.2,6.3,6.3,2.5]
for i in range(4):
    ax = fig.add_subplot(141+i)
    ax.scatter( zz_train[:,2,i], zz_predict[:,i])
    ax.set_ylabel('$orgP_{%s}$'%str(i+1),fontsize = 17)
    ax.set_xlabel('$orgT_{%s}$'%str(i+1),fontsize = 17)
    # ax.text(xx[i],yy[i],r'R$^2$:%4.2f'%r2s_2[i],fontsize = 16)
    ax.tick_params(axis='x', labelsize=14)
    ax.tick_params(axis='y', labelsize=14)
    # if i ==3 : 
        # ax.set_yticks(ticks = [-15,-10,-5,0,5])
    
case = 3
# plt.show()
# fig.savefig('z_true_predict_lg_32_4_wind_pw_zz.jpeg',bbox_inches = 'tight',dpi = 100)

# %%
def scatter_hist(x, y, ax, ax_histx, ax_histy,i,r2):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    
    ax.tick_params(axis="both", labelsize= 16)

    ax_histy.set_xticks([])
    # ax_histx.set_xticks([])
    # ax_histy.set_yticks([])
    ax_histx.set_yticks([])
    ax_histx.spines['top'].set_visible(False)
    ax_histx.spines['right'].set_visible(False)
    ax_histx.spines['bottom'].set_visible(False)
    ax_histx.spines['left'].set_visible(False)
    ax_histy.spines['top'].set_visible(False)
    ax_histy.spines['right'].set_visible(False)
    ax_histy.spines['bottom'].set_visible(False)
    ax_histy.spines['left'].set_visible(False)
    ax.set_xlabel(r'$OrgT_{%s}$'%str(i),fontsize = 18)
    ax.set_ylabel(r'$OrgP_{%s}$'%str(i),fontsize = 18)
    # the scatter plot:
    ax.scatter(x, y)
    ax.text(-1.2,1.2,r'$R^2 = %2.2f$'%r2, fontsize= 18)

    # now determine nice limits by hand:
    binwidth = 0.01
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    # bins = 100
    ax_histx.hist(x, bins=bins)
    ax_histy.hist(y, bins=bins, orientation='horizontal')
    ax.set_ylim(-1.5,1.5)
    ax.set_xlim(-1.5,1.5)
    
def scatter_hist_2(x, y, ax, i,r2):
    # no labels
    ax_histx = ax.twinx()
    ax_histy = ax.twiny()
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)
    
    ax.tick_params(axis="both", labelsize= 16)

    ax_histy.set_xticks([])
    # ax_histx.set_xticks([])
    # ax_histy.set_yticks([])
    ax_histx.set_yticks([])
    ax_histx.spines['top'].set_visible(False)
    ax_histx.spines['right'].set_visible(False)
    ax_histx.spines['bottom'].set_visible(False)
    ax_histx.spines['left'].set_visible(False)
    ax_histy.spines['top'].set_visible(False)
    ax_histy.spines['right'].set_visible(False)
    ax_histy.spines['bottom'].set_visible(False)
    ax_histy.spines['left'].set_visible(False)
    ax.set_xlabel(r'$OrgT_{%s}$'%str(i),fontsize = 18)
    ax.set_ylabel(r'$OrgP_{%s}$'%str(i),fontsize = 18)
    # the scatter plot:
    ax.scatter(x[::6], y[::6],color = 'steelblue',alpha = 0.6,s = 60, facecolors='none')
    ax.text(-.8,.8,r'$R^2 = %2.2f$'%r2, fontsize= 18)
    ax.set_yticks(ticks=[-1,-0.5,0,0.5,1])
    # now determine nice limits by hand:
    binwidth = 0.01
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    # bins = 100
    ax_histx.hist(x, bins=bins,color = 'olivedrab',alpha = 0.8)
    ax_histy.hist(y, bins=bins, orientation='horizontal',color = 'firebrick',alpha = 0.8)
    ax.set_ylim(-1.,1.)
    ax.set_xlim(-1.,1.)
    ax_histy.set_xlim(0,120000)
    ax_histx.set_ylim(0,120000)

# %%
for case in range (4):
    fig = plt.figure(figsize=(6, 6))
    # Create the Axes.
    ax = fig.add_subplot()

    # Draw the scatter plot and marginals.
    scatter_hist_2(0.1*zz_train[:,4,case], 0.1*zz_predict[:,case], ax, case+1,r2s[case] )
    # fig.savefig('org'+str(case+1)+'_w1_lg.jpeg',bbox_inches  ='tight',dpi  =300)

# %%
for case in range (4):
    fig = plt.figure(figsize=(6, 6))
    # Add a gridspec with two rows and two columns and a ratio of 1 to 4 between
    # the size of the marginal axes and the main axes in both directions.
    # Also adjust the subplot parameters for a square plot.
    gs = fig.add_gridspec(2, 2,  width_ratios=(4, 1), height_ratios=(1, 4),
                          left=0.1, right=0.9, bottom=0.1, top=0.9,
                          wspace=0.02, hspace=0.02)
    # Create the Axes.
    ax = fig.add_subplot(gs[1, 0])
    ax_histx = fig.add_subplot(gs[0, 0], sharex=ax)
    ax_histy = fig.add_subplot(gs[1, 1], sharey=ax)
    # Draw the scatter plot and marginals.
    scatter_hist(0.1*zz_train[:,2,case], 0.1*zz_predict[:,case], ax, ax_histx, ax_histy,case+1,r2s[case] )
    fig.savefig('org'+str(case+1)+'_w3_lg.jpeg',bbox_inches  ='tight',dpi  =300)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=0).fit(zz_train[:,-1,:])
labels = kmeans.labels_

# %%
len(np.where(labels==0)[0]),len(np.where(labels==1)[0]),len(np.where(labels==2)[0])#,len(np.where(labels==3)[0])
# Out:
# (101496, 111374, 438022)

# %%
case = 1
inds = np.where(labels == case )[0]
zz = [31543,46615,84864,96588,107939]
fig = plt.figure(figsize=[26,5])
vect = np.arange(0,1.1,0.1)
for i in range(5):
    ax = fig.add_subplot(151+i)

    ax.contourf(x_hr[inds[zz[i]],:,:,0])
fig.savefig('l2_ss.jpeg')

# %%
x_hr = x_hr.reshape(760* 24* 287, 32, 32, 1)

# %%
_=plt.hist(precip.flatten(),bins=100)
_=plt.hist(yflat.flatten(),bins=100)
plt.yscale('log')

# %%
y_out.shape,precip.shape
# Out:
# ((760, 24, 287, 1), (5234880, 1))

# %%
yflat = y_out.reshape(760*24*287)
yflat.shape
# Out:
# (5234880,)

# %%
inds = np.where(yflat>0.01)[0]
yflat = yflat[inds]
precip2 = precip[inds]

# %%
pw_anomaly.shape,precip.shape
# Out:
# ((760, 24, 287, 32, 32, 1), (5234880, 1))
